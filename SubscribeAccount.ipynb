# %% [markdown]
# [🥭 Mango Markets](https://mango.markets/) support is available at: [Docs](https://docs.mango.markets/) | [Discord](https://discord.gg/67jySBhxrg) | [Twitter](https://twitter.com/mangomarkets) | [Github](https://github.com/blockworks-foundation) | [Email](mailto:hello@blockworks.foundation)
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/blockworks-foundation/mango-explorer-examples/HEAD?labpath=SusbscribeAccount.ipynb) [Run this code](https://mybinder.org/v2/gh/blockworks-foundation/mango-explorer-examples/HEAD?labpath=SusbscribeAccount.ipynb) on Binder.
#
# _🏃‍♀️ To run this notebook press the ⏩ icon in the toolbar above._

# %% [markdown]
# # 🥭 Subscribe to Account changes
#
# This code will connect to the _devnet_ cluster and print out the Mango `Account` every time it changes. It will exit after 60 seconds.
#
# The `subscribe()` method takes a lambda callback as a parameter - this lambda will be called with a new `Account` object when an update is received.
#
# This code will exit after 60 seconds.
#
# **NOTE:** This will send an updated `Account` object, including whatever updated values triggered the update. However a proper valuation of an `Account` involves several more Mango data accounts so it's important to fetch all data fresh (including `Group`, `Cache` and all `OpenOrders`) to calculate values.

# %%
import datetime
import mango
import time

from solana.publickey import PublicKey

with mango.ContextBuilder.build(cluster_name="devnet") as context:
    # Load our devnet Random Taker Mango Account - it should have some activity
    group = mango.Group.load(context)
    account = mango.Account.load(context, PublicKey("5JDWiJGmnvs1DZomMV3s9Ev6DAgCQ9Svxd81EHCapjnD"), group)

    manager = mango.IndividualWebSocketSubscriptionManager(context)
    subscription = account.subscribe(context, manager, lambda acc: print(datetime.datetime.now(), "\n", acc))
    manager.open()

    time.sleep(60)

    manager.dispose()

print("Example complete.")
# Out:
#  2022-03-08 15:04:44.612327
#  « Account 'Random Taker', Version.V3 [5JDWiJGmnvs1DZomMV3s9Ev6DAgCQ9Svxd81EHCapjnD]
#     « Metadata Version.V1 - Account: Initialized »
#     Owner: DeekL3W31SyCkQezqztjvxkbJcst1xaEbtnqbN6g48Zt
#     Delegated To: None
#     Group: « Group 'devnet.2' [Ec2enZyoC4nGpEfu2sUNAa2nUGJHWxoUWYSEJ2hNTWTA] »
#     Advanced Orders Account: None
#     MSRM: 0
#     Bankrupt? False
#     Upgradable? True
#     Being Liquidated? False
#     Shared Quote Token:
#         « AccountSlot [15] USDC
#             Net Value:     « InstrumentValue: -58,009,265.91077579 USDC »
#                 Deposited: « InstrumentValue:         0.00000000 USDC » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue: 58,009,265.91077579 USDC » (raw value 57915049.60550518576689071892)
#             Spot OpenOrders: None
#             Perp Account:
#                 None
#         »
#     In Basket: MNGO, BTC, ETH, SOL, SRM, RAY, USDT, ADA, FTT, AVAX, LUNA, BNB, MATIC
#     Basket [13 in basket]:
#         « AccountSlot [0] MNGO
#             Net Value:     « InstrumentValue:         0.00000000 MNGO »
#                 Deposited: « InstrumentValue:         0.00000000 MNGO » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 MNGO » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [1] BTC
#             Net Value:     « InstrumentValue:     1,980.06105897 BTC »
#                 Deposited: « InstrumentValue:     1,980.06105897 BTC » (raw value: 1979.65693456670332395220)
#                 Borrowed:  « InstrumentValue:         0.00000000 BTC » (raw value 0E-20)
#             Spot OpenOrders: 9us8G4KRbym3tdTsmszK8KBqWUgv2KGoAV1o5J2Wj3Z3
#             Perp Account:
#                 « PerpAccount
#                     Base Position: « InstrumentValue:       -89.08680000 BTC »
#                     Quote Position: 2738362602967.77832753598916700000
#                     Long Settled Funding: 3698685.66177972484682001664
#                     Short Settled Funding: 3640403.69971305225838520414
#                     Bids Quantity: 0
#                     Asks Quantity: 0
#                     Taker Base: 1194
#                     Taker Quote: -464216454
#                     MNGO Accrued: « InstrumentValue:         0.00000300 MNGO »
#                     OpenOrders:
#                         « PerpOpenOrders
#                             Orders:
#                                 None
#                         »
#                 »
#         »
#         « AccountSlot [2] ETH
#             Net Value:     « InstrumentValue:         0.00000000 ETH »
#                 Deposited: « InstrumentValue:         0.00000000 ETH » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 ETH » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [3] SOL
#             Net Value:     « InstrumentValue:         0.00000000 SOL »
#                 Deposited: « InstrumentValue:         0.00000000 SOL » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SOL » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [4] SRM
#             Net Value:     « InstrumentValue:         0.00000000 SRM »
#                 Deposited: « InstrumentValue:         0.00000000 SRM » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SRM » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [5] RAY
#             Net Value:     « InstrumentValue:         0.00000000 RAY »
#                 Deposited: « InstrumentValue:         0.00000000 RAY » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 RAY » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [6] USDT
#             Net Value:     « InstrumentValue:         0.00000000 USDT »
#                 Deposited: « InstrumentValue:         0.00000000 USDT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 USDT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [7] ADA
#             Net Value:     « InstrumentValue:         0.00000000 Cardano »
#                 Deposited: « InstrumentValue:         0.00000000 Cardano » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Cardano » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [8] FTT
#             Net Value:     « InstrumentValue:         0.00000000 FTT »
#                 Deposited: « InstrumentValue:         0.00000000 FTT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 FTT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [9] AVAX
#             Net Value:     « InstrumentValue:         0.00000000 Avalanche »
#                 Deposited: « InstrumentValue:         0.00000000 Avalanche » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Avalanche » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [10] LUNA
#             Net Value:     « InstrumentValue:         0.00000000 Terra »
#                 Deposited: « InstrumentValue:         0.00000000 Terra » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Terra » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [11] BNB
#             Net Value:     « InstrumentValue:         0.00000000 Binance Coin »
#                 Deposited: « InstrumentValue:         0.00000000 Binance Coin » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Binance Coin » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [12] MATIC
#             Net Value:     « InstrumentValue:         0.00000000 Polygon »
#                 Deposited: « InstrumentValue:         0.00000000 Polygon » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Polygon » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
# »
#
#  2022-03-08 15:04:49.748144
#  « Account 'Random Taker', Version.V3 [5JDWiJGmnvs1DZomMV3s9Ev6DAgCQ9Svxd81EHCapjnD]
#     « Metadata Version.V1 - Account: Initialized »
#     Owner: DeekL3W31SyCkQezqztjvxkbJcst1xaEbtnqbN6g48Zt
#     Delegated To: None
#     Group: « Group 'devnet.2' [Ec2enZyoC4nGpEfu2sUNAa2nUGJHWxoUWYSEJ2hNTWTA] »
#     Advanced Orders Account: None
#     MSRM: 0
#     Bankrupt? False
#     Upgradable? True
#     Being Liquidated? False
#     Shared Quote Token:
#         « AccountSlot [15] USDC
#             Net Value:     « InstrumentValue: -58,009,265.91077579 USDC »
#                 Deposited: « InstrumentValue:         0.00000000 USDC » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue: 58,009,265.91077579 USDC » (raw value 57915049.60550518576689071892)
#             Spot OpenOrders: None
#             Perp Account:
#                 None
#         »
#     In Basket: MNGO, BTC, ETH, SOL, SRM, RAY, USDT, ADA, FTT, AVAX, LUNA, BNB, MATIC
#     Basket [13 in basket]:
#         « AccountSlot [0] MNGO
#             Net Value:     « InstrumentValue:         0.00000000 MNGO »
#                 Deposited: « InstrumentValue:         0.00000000 MNGO » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 MNGO » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [1] BTC
#             Net Value:     « InstrumentValue:     1,980.06105897 BTC »
#                 Deposited: « InstrumentValue:     1,980.06105897 BTC » (raw value: 1979.65693456670332395220)
#                 Borrowed:  « InstrumentValue:         0.00000000 BTC » (raw value 0E-20)
#             Spot OpenOrders: 9us8G4KRbym3tdTsmszK8KBqWUgv2KGoAV1o5J2Wj3Z3
#             Perp Account:
#                 « PerpAccount
#                     Base Position: « InstrumentValue:       -89.08680000 BTC »
#                     Quote Position: 2733720864351.24654579833093800000
#                     Long Settled Funding: 3698686.13923921557533702753
#                     Short Settled Funding: 3640404.17717254298690221503
#                     Bids Quantity: 0
#                     Asks Quantity: 0
#                     Taker Base: 0
#                     Taker Quote: 0
#                     MNGO Accrued: « InstrumentValue:         0.00000300 MNGO »
#                     OpenOrders:
#                         « PerpOpenOrders
#                             Orders:
#                                 None
#                         »
#                 »
#         »
#         « AccountSlot [2] ETH
#             Net Value:     « InstrumentValue:         0.00000000 ETH »
#                 Deposited: « InstrumentValue:         0.00000000 ETH » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 ETH » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [3] SOL
#             Net Value:     « InstrumentValue:         0.00000000 SOL »
#                 Deposited: « InstrumentValue:         0.00000000 SOL » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SOL » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [4] SRM
#             Net Value:     « InstrumentValue:         0.00000000 SRM »
#                 Deposited: « InstrumentValue:         0.00000000 SRM » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SRM » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [5] RAY
#             Net Value:     « InstrumentValue:         0.00000000 RAY »
#                 Deposited: « InstrumentValue:         0.00000000 RAY » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 RAY » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [6] USDT
#             Net Value:     « InstrumentValue:         0.00000000 USDT »
#                 Deposited: « InstrumentValue:         0.00000000 USDT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 USDT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [7] ADA
#             Net Value:     « InstrumentValue:         0.00000000 Cardano »
#                 Deposited: « InstrumentValue:         0.00000000 Cardano » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Cardano » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [8] FTT
#             Net Value:     « InstrumentValue:         0.00000000 FTT »
#                 Deposited: « InstrumentValue:         0.00000000 FTT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 FTT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [9] AVAX
#             Net Value:     « InstrumentValue:         0.00000000 Avalanche »
#                 Deposited: « InstrumentValue:         0.00000000 Avalanche » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Avalanche » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [10] LUNA
#             Net Value:     « InstrumentValue:         0.00000000 Terra »
#                 Deposited: « InstrumentValue:         0.00000000 Terra » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Terra » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [11] BNB
#             Net Value:     « InstrumentValue:         0.00000000 Binance Coin »
#                 Deposited: « InstrumentValue:         0.00000000 Binance Coin » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Binance Coin » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [12] MATIC
#             Net Value:     « InstrumentValue:         0.00000000 Polygon »
#                 Deposited: « InstrumentValue:         0.00000000 Polygon » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Polygon » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
# »
#
#  2022-03-08 15:04:50.944325
#  « Account 'Random Taker', Version.V3 [5JDWiJGmnvs1DZomMV3s9Ev6DAgCQ9Svxd81EHCapjnD]
#     « Metadata Version.V1 - Account: Initialized »
#     Owner: DeekL3W31SyCkQezqztjvxkbJcst1xaEbtnqbN6g48Zt
#     Delegated To: None
#     Group: « Group 'devnet.2' [Ec2enZyoC4nGpEfu2sUNAa2nUGJHWxoUWYSEJ2hNTWTA] »
#     Advanced Orders Account: None
#     MSRM: 0
#     Bankrupt? False
#     Upgradable? True
#     Being Liquidated? False
#     Shared Quote Token:
#         « AccountSlot [15] USDC
#             Net Value:     « InstrumentValue: -57,989,236.22665968 USDC »
#                 Deposited: « InstrumentValue:         0.00000000 USDC » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue: 57,989,236.22665968 USDC » (raw value 57895052.45279252368576194954)
#             Spot OpenOrders: None
#             Perp Account:
#                 None
#         »
#     In Basket: MNGO, BTC, ETH, SOL, SRM, RAY, USDT, ADA, FTT, AVAX, LUNA, BNB, MATIC
#     Basket [13 in basket]:
#         « AccountSlot [0] MNGO
#             Net Value:     « InstrumentValue:         0.00000000 MNGO »
#                 Deposited: « InstrumentValue:         0.00000000 MNGO » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 MNGO » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [1] BTC
#             Net Value:     « InstrumentValue:     1,979.53665897 BTC »
#                 Deposited: « InstrumentValue:     1,979.53665897 BTC » (raw value: 1979.13264159520878493481)
#                 Borrowed:  « InstrumentValue:         0.00000000 BTC » (raw value 0E-20)
#             Spot OpenOrders: 9us8G4KRbym3tdTsmszK8KBqWUgv2KGoAV1o5J2Wj3Z3
#             Perp Account:
#                 « PerpAccount
#                     Base Position: « InstrumentValue:       -89.08680000 BTC »
#                     Quote Position: 2733720864351.24654579833093800000
#                     Long Settled Funding: 3698686.13923921557533702753
#                     Short Settled Funding: 3640404.17717254298690221503
#                     Bids Quantity: 0
#                     Asks Quantity: 0
#                     Taker Base: 0
#                     Taker Quote: 0
#                     MNGO Accrued: « InstrumentValue:         0.00000300 MNGO »
#                     OpenOrders:
#                         « PerpOpenOrders
#                             Orders:
#                                 None
#                         »
#                 »
#         »
#         « AccountSlot [2] ETH
#             Net Value:     « InstrumentValue:         0.00000000 ETH »
#                 Deposited: « InstrumentValue:         0.00000000 ETH » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 ETH » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [3] SOL
#             Net Value:     « InstrumentValue:         0.00000000 SOL »
#                 Deposited: « InstrumentValue:         0.00000000 SOL » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SOL » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [4] SRM
#             Net Value:     « InstrumentValue:         0.00000000 SRM »
#                 Deposited: « InstrumentValue:         0.00000000 SRM » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SRM » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [5] RAY
#             Net Value:     « InstrumentValue:         0.00000000 RAY »
#                 Deposited: « InstrumentValue:         0.00000000 RAY » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 RAY » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [6] USDT
#             Net Value:     « InstrumentValue:         0.00000000 USDT »
#                 Deposited: « InstrumentValue:         0.00000000 USDT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 USDT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [7] ADA
#             Net Value:     « InstrumentValue:         0.00000000 Cardano »
#                 Deposited: « InstrumentValue:         0.00000000 Cardano » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Cardano » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [8] FTT
#             Net Value:     « InstrumentValue:         0.00000000 FTT »
#                 Deposited: « InstrumentValue:         0.00000000 FTT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 FTT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [9] AVAX
#             Net Value:     « InstrumentValue:         0.00000000 Avalanche »
#                 Deposited: « InstrumentValue:         0.00000000 Avalanche » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Avalanche » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [10] LUNA
#             Net Value:     « InstrumentValue:         0.00000000 Terra »
#                 Deposited: « InstrumentValue:         0.00000000 Terra » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Terra » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [11] BNB
#             Net Value:     « InstrumentValue:         0.00000000 Binance Coin »
#                 Deposited: « InstrumentValue:         0.00000000 Binance Coin » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Binance Coin » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [12] MATIC
#             Net Value:     « InstrumentValue:         0.00000000 Polygon »
#                 Deposited: « InstrumentValue:         0.00000000 Polygon » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Polygon » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
# »
#
#  2022-03-08 15:05:17.044188
#  « Account 'Random Taker', Version.V3 [5JDWiJGmnvs1DZomMV3s9Ev6DAgCQ9Svxd81EHCapjnD]
#     « Metadata Version.V1 - Account: Initialized »
#     Owner: DeekL3W31SyCkQezqztjvxkbJcst1xaEbtnqbN6g48Zt
#     Delegated To: None
#     Group: « Group 'devnet.2' [Ec2enZyoC4nGpEfu2sUNAa2nUGJHWxoUWYSEJ2hNTWTA] »
#     Advanced Orders Account: None
#     MSRM: 0
#     Bankrupt? False
#     Upgradable? True
#     Being Liquidated? False
#     Shared Quote Token:
#         « AccountSlot [15] USDC
#             Net Value:     « InstrumentValue: -57,989,236.22665968 USDC »
#                 Deposited: « InstrumentValue:         0.00000000 USDC » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue: 57,989,236.22665968 USDC » (raw value 57895052.45279252368576194954)
#             Spot OpenOrders: None
#             Perp Account:
#                 None
#         »
#     In Basket: MNGO, BTC, ETH, SOL, SRM, RAY, USDT, ADA, FTT, AVAX, LUNA, BNB, MATIC
#     Basket [13 in basket]:
#         « AccountSlot [0] MNGO
#             Net Value:     « InstrumentValue:         0.00000000 MNGO »
#                 Deposited: « InstrumentValue:         0.00000000 MNGO » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 MNGO » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [1] BTC
#             Net Value:     « InstrumentValue:     1,979.53665897 BTC »
#                 Deposited: « InstrumentValue:     1,979.53665897 BTC » (raw value: 1979.13264159520878493481)
#                 Borrowed:  « InstrumentValue:         0.00000000 BTC » (raw value 0E-20)
#             Spot OpenOrders: 9us8G4KRbym3tdTsmszK8KBqWUgv2KGoAV1o5J2Wj3Z3
#             Perp Account:
#                 « PerpAccount
#                     Base Position: « InstrumentValue:       -89.49600000 BTC »
#                     Quote Position: 2733711409597.01456783339369500000
#                     Long Settled Funding: 3698686.13923921557533702753
#                     Short Settled Funding: 3640404.17717254298690221503
#                     Bids Quantity: 0
#                     Asks Quantity: 0
#                     Taker Base: -4092
#                     Taker Quote: 1575792372
#                     MNGO Accrued: « InstrumentValue:         0.00000300 MNGO »
#                     OpenOrders:
#                         « PerpOpenOrders
#                             Orders:
#                                 None
#                         »
#                 »
#         »
#         « AccountSlot [2] ETH
#             Net Value:     « InstrumentValue:         0.00000000 ETH »
#                 Deposited: « InstrumentValue:         0.00000000 ETH » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 ETH » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [3] SOL
#             Net Value:     « InstrumentValue:         0.00000000 SOL »
#                 Deposited: « InstrumentValue:         0.00000000 SOL » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SOL » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [4] SRM
#             Net Value:     « InstrumentValue:         0.00000000 SRM »
#                 Deposited: « InstrumentValue:         0.00000000 SRM » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SRM » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [5] RAY
#             Net Value:     « InstrumentValue:         0.00000000 RAY »
#                 Deposited: « InstrumentValue:         0.00000000 RAY » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 RAY » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [6] USDT
#             Net Value:     « InstrumentValue:         0.00000000 USDT »
#                 Deposited: « InstrumentValue:         0.00000000 USDT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 USDT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [7] ADA
#             Net Value:     « InstrumentValue:         0.00000000 Cardano »
#                 Deposited: « InstrumentValue:         0.00000000 Cardano » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Cardano » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [8] FTT
#             Net Value:     « InstrumentValue:         0.00000000 FTT »
#                 Deposited: « InstrumentValue:         0.00000000 FTT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 FTT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [9] AVAX
#             Net Value:     « InstrumentValue:         0.00000000 Avalanche »
#                 Deposited: « InstrumentValue:         0.00000000 Avalanche » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Avalanche » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [10] LUNA
#             Net Value:     « InstrumentValue:         0.00000000 Terra »
#                 Deposited: « InstrumentValue:         0.00000000 Terra » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Terra » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [11] BNB
#             Net Value:     « InstrumentValue:         0.00000000 Binance Coin »
#                 Deposited: « InstrumentValue:         0.00000000 Binance Coin » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Binance Coin » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [12] MATIC
#             Net Value:     « InstrumentValue:         0.00000000 Polygon »
#                 Deposited: « InstrumentValue:         0.00000000 Polygon » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Polygon » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
# »
#
#  2022-03-08 15:05:20.952205
#  « Account 'Random Taker', Version.V3 [5JDWiJGmnvs1DZomMV3s9Ev6DAgCQ9Svxd81EHCapjnD]
#     « Metadata Version.V1 - Account: Initialized »
#     Owner: DeekL3W31SyCkQezqztjvxkbJcst1xaEbtnqbN6g48Zt
#     Delegated To: None
#     Group: « Group 'devnet.2' [Ec2enZyoC4nGpEfu2sUNAa2nUGJHWxoUWYSEJ2hNTWTA] »
#     Advanced Orders Account: None
#     MSRM: 0
#     Bankrupt? False
#     Upgradable? True
#     Being Liquidated? False
#     Shared Quote Token:
#         « AccountSlot [15] USDC
#             Net Value:     « InstrumentValue: -57,989,236.22665968 USDC »
#                 Deposited: « InstrumentValue:         0.00000000 USDC » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue: 57,989,236.22665968 USDC » (raw value 57895052.45279252368576194954)
#             Spot OpenOrders: None
#             Perp Account:
#                 None
#         »
#     In Basket: MNGO, BTC, ETH, SOL, SRM, RAY, USDT, ADA, FTT, AVAX, LUNA, BNB, MATIC
#     Basket [13 in basket]:
#         « AccountSlot [0] MNGO
#             Net Value:     « InstrumentValue:         0.00000000 MNGO »
#                 Deposited: « InstrumentValue:         0.00000000 MNGO » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 MNGO » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [1] BTC
#             Net Value:     « InstrumentValue:     1,979.53665897 BTC »
#                 Deposited: « InstrumentValue:     1,979.53665897 BTC » (raw value: 1979.13264159520878493481)
#                 Borrowed:  « InstrumentValue:         0.00000000 BTC » (raw value 0E-20)
#             Spot OpenOrders: 9us8G4KRbym3tdTsmszK8KBqWUgv2KGoAV1o5J2Wj3Z3
#             Perp Account:
#                 « PerpAccount
#                     Base Position: « InstrumentValue:       -89.49600000 BTC »
#                     Quote Position: 2749469335669.97842770034888500000
#                     Long Settled Funding: 3698686.14188041927764416528
#                     Short Settled Funding: 3640404.17981374668920935278
#                     Bids Quantity: 0
#                     Asks Quantity: 0
#                     Taker Base: 0
#                     Taker Quote: 0
#                     MNGO Accrued: « InstrumentValue:         0.00000300 MNGO »
#                     OpenOrders:
#                         « PerpOpenOrders
#                             Orders:
#                                 None
#                         »
#                 »
#         »
#         « AccountSlot [2] ETH
#             Net Value:     « InstrumentValue:         0.00000000 ETH »
#                 Deposited: « InstrumentValue:         0.00000000 ETH » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 ETH » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [3] SOL
#             Net Value:     « InstrumentValue:         0.00000000 SOL »
#                 Deposited: « InstrumentValue:         0.00000000 SOL » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SOL » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [4] SRM
#             Net Value:     « InstrumentValue:         0.00000000 SRM »
#                 Deposited: « InstrumentValue:         0.00000000 SRM » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SRM » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [5] RAY
#             Net Value:     « InstrumentValue:         0.00000000 RAY »
#                 Deposited: « InstrumentValue:         0.00000000 RAY » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 RAY » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [6] USDT
#             Net Value:     « InstrumentValue:         0.00000000 USDT »
#                 Deposited: « InstrumentValue:         0.00000000 USDT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 USDT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [7] ADA
#             Net Value:     « InstrumentValue:         0.00000000 Cardano »
#                 Deposited: « InstrumentValue:         0.00000000 Cardano » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Cardano » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [8] FTT
#             Net Value:     « InstrumentValue:         0.00000000 FTT »
#                 Deposited: « InstrumentValue:         0.00000000 FTT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 FTT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [9] AVAX
#             Net Value:     « InstrumentValue:         0.00000000 Avalanche »
#                 Deposited: « InstrumentValue:         0.00000000 Avalanche » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Avalanche » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [10] LUNA
#             Net Value:     « InstrumentValue:         0.00000000 Terra »
#                 Deposited: « InstrumentValue:         0.00000000 Terra » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Terra » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [11] BNB
#             Net Value:     « InstrumentValue:         0.00000000 Binance Coin »
#                 Deposited: « InstrumentValue:         0.00000000 Binance Coin » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Binance Coin » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [12] MATIC
#             Net Value:     « InstrumentValue:         0.00000000 Polygon »
#                 Deposited: « InstrumentValue:         0.00000000 Polygon » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Polygon » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
# »
#
#  2022-03-08 15:05:22.517910
#  « Account 'Random Taker', Version.V3 [5JDWiJGmnvs1DZomMV3s9Ev6DAgCQ9Svxd81EHCapjnD]
#     « Metadata Version.V1 - Account: Initialized »
#     Owner: DeekL3W31SyCkQezqztjvxkbJcst1xaEbtnqbN6g48Zt
#     Delegated To: None
#     Group: « Group 'devnet.2' [Ec2enZyoC4nGpEfu2sUNAa2nUGJHWxoUWYSEJ2hNTWTA] »
#     Advanced Orders Account: None
#     MSRM: 0
#     Bankrupt? False
#     Upgradable? True
#     Being Liquidated? False
#     Shared Quote Token:
#         « AccountSlot [15] USDC
#             Net Value:     « InstrumentValue: -57,989,236.22665968 USDC »
#                 Deposited: « InstrumentValue:         0.00000000 USDC » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue: 57,989,236.22665968 USDC » (raw value 57895052.45279252368576194954)
#             Spot OpenOrders: None
#             Perp Account:
#                 None
#         »
#     In Basket: MNGO, BTC, ETH, SOL, SRM, RAY, USDT, ADA, FTT, AVAX, LUNA, BNB, MATIC
#     Basket [13 in basket]:
#         « AccountSlot [0] MNGO
#             Net Value:     « InstrumentValue:         0.00000000 MNGO »
#                 Deposited: « InstrumentValue:         0.00000000 MNGO » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 MNGO » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [1] BTC
#             Net Value:     « InstrumentValue:     1,979.53665897 BTC »
#                 Deposited: « InstrumentValue:     1,979.53665897 BTC » (raw value: 1979.13264159520878493481)
#                 Borrowed:  « InstrumentValue:         0.00000000 BTC » (raw value 0E-20)
#             Spot OpenOrders: 9us8G4KRbym3tdTsmszK8KBqWUgv2KGoAV1o5J2Wj3Z3
#             Perp Account:
#                 « PerpAccount
#                     Base Position: « InstrumentValue:       -89.49600000 BTC »
#                     Quote Position: 2749469335669.97842770034888500000
#                     Long Settled Funding: 3698686.14188041927764416528
#                     Short Settled Funding: 3640404.17981374668920935278
#                     Bids Quantity: 0
#                     Asks Quantity: 0
#                     Taker Base: 0
#                     Taker Quote: 0
#                     MNGO Accrued: « InstrumentValue:         0.00000300 MNGO »
#                     OpenOrders:
#                         « PerpOpenOrders
#                             Orders:
#                                 None
#                         »
#                 »
#         »
#         « AccountSlot [2] ETH
#             Net Value:     « InstrumentValue:         0.00000000 ETH »
#                 Deposited: « InstrumentValue:         0.00000000 ETH » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 ETH » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [3] SOL
#             Net Value:     « InstrumentValue:         0.00000000 SOL »
#                 Deposited: « InstrumentValue:         0.00000000 SOL » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SOL » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [4] SRM
#             Net Value:     « InstrumentValue:         0.00000000 SRM »
#                 Deposited: « InstrumentValue:         0.00000000 SRM » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SRM » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [5] RAY
#             Net Value:     « InstrumentValue:         0.00000000 RAY »
#                 Deposited: « InstrumentValue:         0.00000000 RAY » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 RAY » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [6] USDT
#             Net Value:     « InstrumentValue:         0.00000000 USDT »
#                 Deposited: « InstrumentValue:         0.00000000 USDT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 USDT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [7] ADA
#             Net Value:     « InstrumentValue:         0.00000000 Cardano »
#                 Deposited: « InstrumentValue:         0.00000000 Cardano » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Cardano » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [8] FTT
#             Net Value:     « InstrumentValue:         0.00000000 FTT »
#                 Deposited: « InstrumentValue:         0.00000000 FTT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 FTT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [9] AVAX
#             Net Value:     « InstrumentValue:         0.00000000 Avalanche »
#                 Deposited: « InstrumentValue:         0.00000000 Avalanche » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Avalanche » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [10] LUNA
#             Net Value:     « InstrumentValue:         0.00000000 Terra »
#                 Deposited: « InstrumentValue:         0.00000000 Terra » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Terra » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [11] BNB
#             Net Value:     « InstrumentValue:         0.00000000 Binance Coin »
#                 Deposited: « InstrumentValue:         0.00000000 Binance Coin » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Binance Coin » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [12] MATIC
#             Net Value:     « InstrumentValue:         0.00000000 Polygon »
#                 Deposited: « InstrumentValue:         0.00000000 Polygon » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Polygon » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
# »
#
#  2022-03-08 15:05:23.280789
#  « Account 'Random Taker', Version.V3 [5JDWiJGmnvs1DZomMV3s9Ev6DAgCQ9Svxd81EHCapjnD]
#     « Metadata Version.V1 - Account: Initialized »
#     Owner: DeekL3W31SyCkQezqztjvxkbJcst1xaEbtnqbN6g48Zt
#     Delegated To: None
#     Group: « Group 'devnet.2' [Ec2enZyoC4nGpEfu2sUNAa2nUGJHWxoUWYSEJ2hNTWTA] »
#     Advanced Orders Account: None
#     MSRM: 0
#     Bankrupt? False
#     Upgradable? True
#     Being Liquidated? False
#     Shared Quote Token:
#         « AccountSlot [15] USDC
#             Net Value:     « InstrumentValue: -57,998,861.57793798 USDC »
#                 Deposited: « InstrumentValue:         0.00000000 USDC » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue: 57,998,861.57793798 USDC » (raw value 57904662.17096428708395094986)
#             Spot OpenOrders: None
#             Perp Account:
#                 None
#         »
#     In Basket: MNGO, BTC, ETH, SOL, SRM, RAY, USDT, ADA, FTT, AVAX, LUNA, BNB, MATIC
#     Basket [13 in basket]:
#         « AccountSlot [0] MNGO
#             Net Value:     « InstrumentValue:         0.00000000 MNGO »
#                 Deposited: « InstrumentValue:         0.00000000 MNGO » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 MNGO » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [1] BTC
#             Net Value:     « InstrumentValue:     1,979.78565897 BTC »
#                 Deposited: « InstrumentValue:     1,979.78565897 BTC » (raw value: 1979.38159077494137605413)
#                 Borrowed:  « InstrumentValue:         0.00000000 BTC » (raw value 0E-20)
#             Spot OpenOrders: 9us8G4KRbym3tdTsmszK8KBqWUgv2KGoAV1o5J2Wj3Z3
#             Perp Account:
#                 « PerpAccount
#                     Base Position: « InstrumentValue:       -89.49600000 BTC »
#                     Quote Position: 2749469335669.97842770034888500000
#                     Long Settled Funding: 3698686.14188041927764416528
#                     Short Settled Funding: 3640404.17981374668920935278
#                     Bids Quantity: 0
#                     Asks Quantity: 0
#                     Taker Base: 0
#                     Taker Quote: 0
#                     MNGO Accrued: « InstrumentValue:         0.00000300 MNGO »
#                     OpenOrders:
#                         « PerpOpenOrders
#                             Orders:
#                                 None
#                         »
#                 »
#         »
#         « AccountSlot [2] ETH
#             Net Value:     « InstrumentValue:         0.00000000 ETH »
#                 Deposited: « InstrumentValue:         0.00000000 ETH » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 ETH » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [3] SOL
#             Net Value:     « InstrumentValue:         0.00000000 SOL »
#                 Deposited: « InstrumentValue:         0.00000000 SOL » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SOL » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [4] SRM
#             Net Value:     « InstrumentValue:         0.00000000 SRM »
#                 Deposited: « InstrumentValue:         0.00000000 SRM » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 SRM » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [5] RAY
#             Net Value:     « InstrumentValue:         0.00000000 RAY »
#                 Deposited: « InstrumentValue:         0.00000000 RAY » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 RAY » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [6] USDT
#             Net Value:     « InstrumentValue:         0.00000000 USDT »
#                 Deposited: « InstrumentValue:         0.00000000 USDT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 USDT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [7] ADA
#             Net Value:     « InstrumentValue:         0.00000000 Cardano »
#                 Deposited: « InstrumentValue:         0.00000000 Cardano » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Cardano » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [8] FTT
#             Net Value:     « InstrumentValue:         0.00000000 FTT »
#                 Deposited: « InstrumentValue:         0.00000000 FTT » (raw value: 0E-20)
#                 Borrowed:  « InstrumentValue:         0.00000000 FTT » (raw value 0E-20)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [9] AVAX
#             Net Value:     « InstrumentValue:         0.00000000 Avalanche »
#                 Deposited: « InstrumentValue:         0.00000000 Avalanche » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Avalanche » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [10] LUNA
#             Net Value:     « InstrumentValue:         0.00000000 Terra »
#                 Deposited: « InstrumentValue:         0.00000000 Terra » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Terra » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [11] BNB
#             Net Value:     « InstrumentValue:         0.00000000 Binance Coin »
#                 Deposited: « InstrumentValue:         0.00000000 Binance Coin » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Binance Coin » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
#         « AccountSlot [12] MATIC
#             Net Value:     « InstrumentValue:         0.00000000 Polygon »
#                 Deposited: « InstrumentValue:         0.00000000 Polygon » (raw value: 0)
#                 Borrowed:  « InstrumentValue:         0.00000000 Polygon » (raw value 0)
#             Spot OpenOrders: None
#             Perp Account:
#                 « PerpAccount (empty) »
#         »
# »
# Example complete.
